# %% [markdown]
# # Collecting images of humans for our model.
#
# > Here we are using a library that uses google images api to fetch images according to given keywords.

# %%
# %pip install git+https://github.com/Joeclinton1/google-images-download.git
# Out:
# ...
#   Cloning https://github.com/Joeclinton1/google-images-download.git to /private/var/folders/g_/1cswnpys3lb0qssnydw3brsw0000gn/T/pip-req-build-nu1cko3v
#   Running command git clone -q https://github.com/Joeclinton1/google-images-download.git /private/var/folders/g_/1cswnpys3lb0qssnydw3brsw0000gn/T/pip-req-build-nu1cko3v
#   Resolved https://github.com/Joeclinton1/google-images-download.git to commit c773e1c7d12f30c24e793e1963035386764a6248
# ...
#      |████████████████████████████████| 958 kB 814 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 359 kB 10.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.8 MB 989 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 55 kB 1.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 58 kB 1.4 MB/s eta 0:00:01
# ...
#   Created wheel for google-images-download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=15638 sha256=a9a344815b956b6c9593545b8992ad65bb74caf18c48d0ead924340323f1a3f7
# ...

# %%
from google_images_download import google_images_download
response = google_images_download.googleimagesdownload()

# %%
arguments = {"keywords" : "full body picture person", "limit": 100, "format": "jpg", "print_urls":True}
paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = full body picture person
# Evaluating...
# Starting Download...
# Image URL: https://thumbs.dreamstime.com/z/full-body-picture-smiling-casual-man-standing-white-background-full-body-picture-smiling-casual-man-standing-white-141964114.jpg
# Completed Image ====> 1.full-body-picture-smiling-casual-man-standing-white-background-full-body-picture-smiling-casual-man-standing-white-141964114.jpg
# Image URL: https://media.istockphoto.com/photos/full-body-picture-of-young-handsome-man-dancing-picture-id489614182
# Completed Image ====> 2.full-body-picture-of-young-handsome-man-dancing-picture-id489614182.jpg
# Image URL: https://thumbs.dreamstime.com/z/young-latin-man-success-successful-smiling-happy-full-body-portrait-thumbs-up-people-isolated-white-young-latin-man-success-148353817.jpg
# Completed Image ====> 3.young-latin-man-success-successful-smiling-happy-full-body-portrait-thumbs-up-people-isolated-white-young-latin-man-success-148353817.jpg
# ...

# %%
arguments = {"keywords" : "portrait people face", "limit": 100, "format": "jpg"}
paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = portrait people face
# Evaluating...
# Starting Download...
# Completed Image ====> 1.photo-1554151228-14d9def656e4.jpg
# Completed Image ====> 2.headshots_prague-emotional-portrait-of-a-smiling-entrepreneur-1.jpg
# Completed Image ====> 3.54057828-negocio-la-gente-y-el-concepto-de-retrato-cara-sonriente-hombre-de-negocios-o-el-retrato.jpg.webp
# Completed Image ====> 4.photo-1544005313-94ddf0286df2.jpg
# Completed Image ====> 5.06860198e9092ffd29c40ba47f3656bf.jpg
# Completed Image ====> 6.dbc23aa0d94e95eac90f5eca466b26a9.jpg
# Completed Image ====> 7.portrait-indian-people-street-puducherry-india-december-circa-years-man-serious-face-village-front-view-vibrant-174355138.jpg
# Completed Image ====> 8.photo-1438761681033-6461ffad8d80.jpg
# Completed Image ====> 9.people-portrait-child-poverty-141651.jpeg
# Completed Image ====> 10.360_f_197116416_hpfttxsojmvmqu99n6hgp4xx0ejya4m7.jpg
# ...
